# %%
def keep_eves(nums):
  new_list=filter (lambda num: num % 2 ==0, nums )
  return list(new_list)

print (keep_eves([2,3,45,6,6,2.44,66]))
# Out:
# [2, 6, 6, 66]

# %%
def longlengths(string):
  return []

print(longlengths(['a','ab','cd','efg','hi','j','KLM']))
# Out:
# []

# %%
L1=[1,2,3]
L2=[4,5,6]
L3=[]

for i in range(len(L1)):
   L3.append(L1[i] + L2[i])
print (i)
print (L3)
# Out:
# 2
# [5, 7, 9]

# %%
L1=[1,2,3]
L2=[4,5,6]
L4=list(zip(L1,L2))
print(L4)
# Out:
# [(1, 4), (2, 5), (3, 6)]
