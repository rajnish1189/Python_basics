# %%
import pandas as pd
import researchpy as rp
from scipy import stats
import io
from google.colab import files


uploaded = files.upload()
df= pd.read_csv(io.BytesIO(uploaded['Study impact and analysis of Government apps222.csv']))
# Out:
#      <input type="file" id="files-497dd6a0-a6a2-4781-bf6f-feade94cb6dd" name="files[]" multiple disabled />
#      <output id="result-497dd6a0-a6a2-4781-bf6f-feade94cb6dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Study impact and analysis of Government apps222.csv to Study impact and analysis of Government apps222.csv

# %%
pip install researchpy

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
def drop_maybe(series):
    if series.lower() == 'yes' or series.lower() == 'no':
        return series
    else:
        return

# %%
dfr=rp.summary_cat(df[['Why you use app other than IRCTC?','Why you use app other than BHIM?']])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import io
from google.colab import files

Variable_12=dfr["Variable"]
outcome123_data=dfr["Outcome"]
Count_data=dfr["Count"]
percent_data=dfr["Percent"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"]
labels=list(l_names)
print(labels)
explode = (0.1, 0, 0)  
plt.pie(Variable_12,
autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("abc")
plt.show()
# Out:
# ['Bhim', 'IRCTC', 'Percent', 'abc']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-a70d25c629b8> in <module>()
#      13 explode = (0.1, 0, 0)
#      14 plt.pie(Variable_12,
# ---> 15 autopct='%1.1f%%', shadow=True, startangle=90)
#      16 plt.title("abc")
#      17 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2779         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2780         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2781         data is not None else {}))
#    2782
#    2783
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
 str= 'Hello World!'

# %%
# Out:
#   File "<ipython-input-15-e6aa70ef72c8>", line 1
#     print str([0])
#             ^
# SyntaxError: invalid syntax

# %%
print("W", end =' ')
print("Z", end =' ')
print("Y", end =' ')
print("X", end =' ')
# Out:
# W Z Y X

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns
import pandas as pd
# %matplotlib inline

cols = ['age', 'workclass', 'fnlwg', 'education', 'education-num', 
        'marital-status','occupation','relationship', 'race','sex',
        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
data = pd.read_csv('census.csv', names=cols)

#Create a column for work hour categories.
def process_hours(df):
    cut_points = [0,9,19,29,39,49,1000]
    label_names = ["0-9","10-19","20-29","30-39","40-49","50+"]
    df["hours_per_week_categories"] = pd.cut(df["hours-per-week"],
                                             cut_points,labels=label_names)
    return df

data = process_hours(data)
workhour_by_sex = data[['sex', 'hours_per_week_categories']]
workhour_by_sex.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d9730b2b50db> in <module>()
#       9         'marital-status','occupation','relationship', 'race','sex',
#      10         'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
# ---> 11 data = pd.read_csv('census.csv', names=cols)
#      12
#      13 #Create a column for work hour categories.
#
# ...
