# %%
Broke=[]
lst_check = ['plums', 'watermelon', 'kiwi', 'strawberries', 'blueberries', 'peaches', 'apples', 'mangos', 'papaya']

lst = ['plums', 'watermelon', 'kiwi', 'strawberries', 'blueberries', 'peaches', 'apples', 'mangos', 'papaya']
A=lst[0]
B=lst[1]
C=lst[2]
D=lst[3]
E=lst[4]
F=lst[5]
G=lst[6]
H=lst[7]
I=lst[8]

Frik=Broke.append(A+B+C+D+E+F+G+H+I)
for i in Frik:
    s='Fruit:'
 q=
print(Broke)
# Out:
# ['plumswatermelonkiwistrawberriesblueberriespeachesapplesmangospapaya']

# %%
test_list = ['\rgfg\t\n', 'is\n', '\t\tbest\r'] 
  
# printing list 
print("The original list : " + str(test_list)) 
  
# Remove trailing / leading special characters from strings list 
# Using map() + str.strip() 
res = list(map(str.strip, test_list)) 
  
# Printing result 
print("List after removal of special characters : " + str(res))
# Out:
# The original list : ['\rgfg\t\n', 'is\n', '\t\tbest\r']
# List after removal of special characters : ['gfg', 'is', 'best']
