# %%
spark-submit --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d3ddc54039e7> in <module>()
# ----> 1 spark-submit --version
#
# NameError: name 'spark' is not defined
